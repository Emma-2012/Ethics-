# %%
# Data manipulation and analysis 
import numpy as np 
import pandas as pd # Data visualization 
import matplotlib.pyplot as plt 
import seaborn as sns 
# import plotly.express as px
# import bokeh.plotting as bk 

# Statistical analysis and machine learning from scipy 
# import stats from sklearn.model_selection 
# import train_test_split from sklearn.linear_model 
# import LinearRegression from sklearn.metrics 
# import mean_squared_error, r2_score 
# import statsmodels.api as sm

# %%
df = pd.read_csv('Dataset/MathE dataset.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Student ID Student Country  Question ID  Type of Answer Question Level  \
# 0         647         Ireland           77               0          Basic
# 1          41        Portugal           77               1          Basic
# 2         340        Portugal           77               1          Basic
# 3         641           Italy           77               0          Basic
# 4         669        Portugal           77               1          Basic
#
#         Topic    Subtopic                                           Keywords
# 0  Statistics  Statistics  Stem and Leaf diagram Relative frequency Sampl...
# 1  Statistics  Statistics  Stem and Leaf diagram Relative frequency Sampl...
# 2  Statistics  Statistics  Stem and Leaf diagram Relative frequency Sampl...
# 3  Statistics  Statistics  Stem and Leaf diagram Relative frequency Sampl...
# 4  Statistics  Statistics  Stem and Leaf diagram Relative frequency Sampl...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9546 entries, 0 to 9545
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student ID       9546 non-null   int64
#  1   Student Country  9546 non-null   object
#  2   Question ID      9546 non-null   int64
#  3   Type of Answer   9546 non-null   int64
#  4   Question Level   9546 non-null   object
#  5   Topic            9546 non-null   object
#  6   Subtopic         9546 non-null   object
#  7   Keywords         9546 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 596.8+ KB

# %%
df.describe()
# Out:
#         Student ID  Question ID  Type of Answer
# count  9546.000000  9546.000000     9546.000000
# mean    775.402263   478.912319        0.468259
# std     460.590559   249.244061        0.499018
# min      26.000000    77.000000        0.000000
# 25%     380.000000   323.000000        0.000000
# 50%     885.000000   428.000000        0.000000
# 75%    1219.000000   571.000000        1.000000
# max    1565.000000  1549.000000        1.000000

# %%
df.shape
# Out:
# (9546, 8)

# %%
df.duplicated().sum().sum()
# Out:
# np.int64(2083)

# %%
df['Type of Answer'].unique()
# Out:
# array([0, 1])

# %%
df['Question Level'].unique()
# Out:
# array(['Basic', 'Advanced'], dtype=object)

# %% [markdown]
# Working on outliers
# Working on imbalance data
# Unnormal data
# duplicate data

# %%
duplicate_rows = df[df.duplicated()] 
duplicate_rows
# Out:
#       Student ID Student Country  Question ID  Type of Answer Question Level  \
# 29            41        Portugal           79               1          Basic
# 36            57        Portugal           79               0          Basic
# 79           181           Italy           83               0          Basic
# 89          1557        Portugal           87               0       Advanced
# 91           854           Italy           88               1          Basic
# ...          ...             ...          ...             ...            ...
# 9524         175           Italy         1475               0          Basic
# 9529         175           Italy         1485               1          Basic
# 9531         175           Italy         1486               1          Basic
# 9533         175           Italy         1487               1          Basic
# 9540         175           Italy         1496               0          Basic
#
#                                     Topic                    Subtopic  \
# 29                             Statistics                  Statistics
# 36                             Statistics                  Statistics
# 79    Real Functions of a single variable  Domain, Image and Graphics
# 89    Real Functions of a single variable       Limits and Continuity
# 91                         Linear Algebra              Linear Systems
# ...                                   ...                         ...
# 9524                      Complex Numbers             Complex Numbers
# 9529                      Complex Numbers             Complex Numbers
# 9531                      Complex Numbers             Complex Numbers
# 9533                      Complex Numbers             Complex Numbers
# 9540                      Complex Numbers             Complex Numbers
#
#                                                Keywords
# 29    Stem and Leaf diagram Relative frequency Sampl...
# 36    Stem and Leaf diagram Relative frequency Sampl...
# 79                           Domain Image of a function
# 89                           Indeterminate forms Limits
# 91    Inconsistent system Square linear system Solut...
# ...                                                 ...
# 9524  Algebraic form Real part Equations involving c...
# 9529                    Operations with complex numbers
# 9531                    Operations with complex numbers
# 9533  Modulus of a complex number Algebraic form Rea...
# 9540                    Operations with complex numbers
#
# [2083 rows x 8 columns]

# %%
duplicates = df[df.duplicated(keep=False)]

duplicates.to_csv('duplicates.csv', index=False)

# %%
# Remove duplicates (keep the first occurrence by default) 
df_no_dup = df.drop_duplicates()

# %%
df_no_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7463 entries, 0 to 9545
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student ID       7463 non-null   int64
#  1   Student Country  7463 non-null   object
#  2   Question ID      7463 non-null   int64
#  3   Type of Answer   7463 non-null   int64
#  4   Question Level   7463 non-null   object
#  5   Topic            7463 non-null   object
#  6   Subtopic         7463 non-null   object
#  7   Keywords         7463 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 524.7+ KB

# %%
df_no_dup['Question Level'].value_counts().plot(kind='bar', color=['skyblue','gold'])
plt.title ('Question level Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
from sklearn.utils import resample

df_majority= df_no_dup[df_no_dup['Question Level'] == 'Basic'] 
df_minority= df_no_dup[df_no_dup['Question Level'] == 'Advanced'] 

#oversampling the minority class
df_min_over= resample(df_minority, replace= True, n_samples= len(df_majority),
random_state = 42 )

df_balance= pd.concat([df_majority,df_min_over] )
df_balance['Question Level'].value_counts()
# Out:
# Question Level
# Basic       6053
# Advanced    6053
# Name: count, dtype: int64

# %%
# Visualize the new class distribution 
df_balance['Question Level'].value_counts().plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Question Level Distribution After Oversampling') 
plt.xlabel('Question Level') 
plt.ylabel('Count') 
plt.show()

# %%
# Check the data types of the columns in df_balance 
numerical_columns = df_balance.select_dtypes(include=['int64', 'float64']).columns.tolist() 
categorical_columns = df_balance.select_dtypes(include=['object', 'category']).columns.tolist() 


# Step 2: Separate the numerical and categorical columns into two DataFrames 
df_numerical = df_balance[numerical_columns] 
df_categorical = df_balance[categorical_columns] 


# Display the results print("Numerical columns:", numerical_columns) print("Categorical columns:", categorical_columns) 

# Display the corresponding DataFrames 
print("\nNumerical DataFrame:") 
print(df_numerical.head()) 
print("\nCategorical DataFrame:") 
print(df_categorical.head())
# Out:
# Numerical DataFrame:
#    Student ID  Question ID  Type of Answer
# 0         647           77               0
# 1          41           77               1
# 2         340           77               1
# 3         641           77               0
# 4         669           77               1
#
# Categorical DataFrame:
#   Student Country Question Level       Topic    Subtopic  \
# 0         Ireland          Basic  Statistics  Statistics
# 1        Portugal          Basic  Statistics  Statistics
# 2        Portugal          Basic  Statistics  Statistics
# 3           Italy          Basic  Statistics  Statistics
# 4        Portugal          Basic  Statistics  Statistics
#
#                                             Keywords
# 0  Stem and Leaf diagram Relative frequency Sampl...
# 1  Stem and Leaf diagram Relative frequency Sampl...
# 2  Stem and Leaf diagram Relative frequency Sampl...
# 3  Stem and Leaf diagram Relative frequency Sampl...
# 4  Stem and Leaf diagram Relative frequency Sampl...

# %%
# Define the target and features
target_column = 'Question Level'
feature_columns = ['Student ID', 'Student Country', 'Question ID', 'Type of Answer', 'Topic', 'Subtopic', 'Keywords']

X = df_balance[feature_columns]  # Features
y = df_balance[target_column]   # Target
X
# Out:
#       Student ID Student Country  Question ID  Type of Answer  \
# 0            647         Ireland           77               0
# 1             41        Portugal           77               1
# 2            340        Portugal           77               1
# 3            641           Italy           77               0
# 4            669        Portugal           77               1
# ...          ...             ...          ...             ...
# 3069         466        Portugal          359               1
# 7194         776        Portugal          574               1
# 5046         955       Lithuania          432               0
# 8155          81       Lithuania          781               0
# 5895         168        Portugal          449               0
#
#                   Topic                Subtopic  \
# 0            Statistics              Statistics
# 1            Statistics              Statistics
# 2            Statistics              Statistics
# 3            Statistics              Statistics
# 4            Statistics              Statistics
# ...                 ...                     ...
# 3069    Complex Numbers         Complex Numbers
# 7194  Analytic Geometry       Analytic Geometry
# 5046     Linear Algebra           Vector Spaces
# 8155     Linear Algebra  Linear Transformations
# 5895     Linear Algebra           Vector Spaces
#
#                                                Keywords
# 0     Stem and Leaf diagram Relative frequency Sampl...
# 1     Stem and Leaf diagram Relative frequency Sampl...
# 2     Stem and Leaf diagram Relative frequency Sampl...
# 3     Stem and Leaf diagram Relative frequency Sampl...
# 4     Stem and Leaf diagram Relative frequency Sampl...
# ...                                                 ...
# 3069  Principal argument Trigonometric form Modulus ...
# 7194  Collinearity Orthogonality Distance Scalar pro...
# 5046  Linear independence Subspace Linear combinatio...
# 8155                                       Range Kernel
# 5895                  Euclidean spaces Orthogonal basis
#
# [12106 rows x 7 columns]

# %%
y
# Out:
# 0          Basic
# 1          Basic
# 2          Basic
# 3          Basic
# 4          Basic
#           ...
# 3069    Advanced
# 7194    Advanced
# 5046    Advanced
# 8155    Advanced
# 5895    Advanced
# Name: Question Level, Length: 12106, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)  # Encode 'Basic' as 0 and 'Advanced' as 1

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
X['Keywords'].unique()
# Out:
# array(['Stem and Leaf diagram Relative frequency Sample Frequency',
#        'Population Variance Median Standard deviation Mode Quantile Sample Mean',
#        'Mean Median Mode',
#        'Logarithmic rule Power rule Exponential rule Trigonometric rules Product rule',
#        'Domain Image of a function', 'Indeterminate forms Limits',
#        'Inconsistent system Square linear system Solution of linear system Undetermined solution of linear system Consistent system',
#        'Square linear system Inconsistent system Solution of linear system Undetermined solution of linear system Consistent system',
#        'Consistent system Inconsistent system Solution of linear system Undetermined solution of linear system',
#        'Consistent system Square linear system Inconsistent system Solution of linear system Undetermined solution of linear system',
#        'Product rule Logarithmic rule Trigonometric rules',
#        'Trigonometric rules Product rule Sum rule Logarithmic rule Power rule',
#        'Trigonometric rules Product rule Sum rule Logarithmic rule Power rule Exponential rule',
#        'Trigonometric rules Product rule Sum rule Power rule',
#        'Simplify expressions',
#        'Inverse matrix  Commuting matrices Solve matrix equation Matrix operations Matrix rank Determinant computation Matrix multiplication Determinant properties Symmetric matrix',
#        'Determinant properties Symmetric matrix Inverse matrix  Commuting matrices Solve matrix equation Matrix operations Matrix rank Determinant computation Matrix multiplication',
#        'Matrix multiplication Determinant computation Determinant properties Symmetric matrix Inverse matrix  Linearly independent rows Commuting matrices Solve matrix equation Matrix operations Matrix rank',
#        'Matrix multiplication Determinant computation Determinant properties Symmetric matrix Inverse matrix  Commuting matrices Solve matrix equation Matrix operations Matrix rank',
#        'Determinant computation Determinant properties Inverse matrix  Matrix operations',
#        'Determinant computation Determinant properties',
#        'Symmetric matrix Determinant computation Determinant properties',
#        'Matrix rank Matrix operations Matrix multiplication Symmetric matrix Determinant computation Commuting matrices Determinant properties Inverse matrix  Solve matrix equation',
#        'Matrix equivalent - echelon Matrix rank Matrix operations Matrix multiplication Symmetric matrix Linearly independent rows Determinant computation Commuting matrices Determinant properties Inverse matrix  Solve matrix equation',
#        'Matrix operations Determinant computation Determinant properties Inverse matrix ',
#        'Matrix operations Matrix multiplication',
#        'Trigonometric rules Product rule',
#        'Trigonometric rules Logarithmic rule', 'Trigonometric rules',
#        'Product rule Trigonometric rules Logarithmic rule',
#        'Separable variables equation', 'First order',
#        'Stationary point Minimum Optimal solution Lagrange multipliers',
#        'Lagrange multipliers Maximum Minimum',
#        'Linear differential equation',
#        'Homogeneous equation Cauchy problem',
#        'Linear differential equation Integral curve Cauchy problem',
#        'Linear differential equation Homogeneous equation',
#        'Sample Population Mean Variance Standard deviation Median Mode Quantile',
#        'Mean Variance Standard deviation Median Mode',
#        'Quantile Frequency Sample Mean Variance Standard deviation Median Mode',
#        'Quantile Population Sample Mean Variance Standard deviation Median Mode',
#        'Frequency Sample Stem and Leaf diagram Variance Standard deviation Relative frequency',
#        'Frequency Quantile Mean Variance Median Mode',
#        'Population Sample',
#        'Mode Quantile Population Data type Sample Mean Standard deviation Variance Median',
#        'Frequency Mode Quantile Population Data type Sample Relative frequency Mean Standard deviation Variance Median',
#        'Median Frequency Mode Quantile Population Data type Sample Relative frequency Mean Standard deviation Variance',
#        'Trigonometric substitution Simple integration',
#        'Standard deviation Variance Median Frequency Mode Outliers Quantile Interquartile range Population Data type Sample Relative frequency Mean',
#        'Chi square distribution Student distribution Quantile Hypothesis testing',
#        'Student distribution Confidence interval Point estimate Hypothesis testing',
#        'Student distribution Hypothesis testing', 'Linear regression',
#        'Undetermined solution of linear system Consistent system Inconsistent system Solution of linear system',
#        'Solution of linear system Undetermined solution of linear system Consistent system Square linear system Inconsistent system',
#        'Inconsistent system Solution of linear system Undetermined solution of linear system Consistent system Square linear system',
#        'Inconsistent system Solution of linear system Undetermined solution of linear system Consistent system',
#        'Undetermined solution of linear system Consistent system Square linear system Inconsistent system Solution of linear system',
#        'Quotient rule Product rule Trigonometric rules',
#        'Quotient rule Product rule Power rule Trigonometric rules',
#        'Logarithmic rule Trigonometric rules',
#        'Logarithmic rule Power rule Trigonometric rules',
#        'Trigonometric rules Product rule Logarithmic rule',
#        'Gradient First order', 'First order Gradient', 'Chain rule',
#        'First order Second order', 'Product rule Trigonometric rules',
#        'Logarithmic rule Product rule Trigonometric rules',
#        'Linear application Linearity', 'Linear programming',
#        'Excel solver add-in Simplex method Linear programming',
#        'Matrix of a linear transformation',
#        'Kernel Isomorphism Injective linear application Range',
#        'Event Axioms of probability Sample space',
#        'Sample space Addition  multiplication  and total probability rules Event Axioms of probability',
#        'Event Axioms of probability', 'Sample space Event',
#        'Addition  multiplication  and total probability rules Sample space Event Axioms of probability',
#        'Event Axioms of probability Addition  multiplication  and total probability rules Sample space',
#        'Event Addition  multiplication  and total probability rules Independence',
#        'Axioms of probability Event Addition  multiplication  and total probability rules Sample space',
#        'Direct inspection Simple integration',
#        'Span Linear combination Subspace', 'Event Sample space',
#        'Subspace Span Linear combination',
#        'Matrix of a linear transformation Linear application Linearity',
#        'Linearity Linear application', 'Range Kernel',
#        'Operations with complex numbers Imaginary part Modulus of a complex number Conjugate number Real part',
#        'Real part Operations with complex numbers Imaginary part Modulus of a complex number Conjugate number',
#        'Conjugate number Real part Operations with complex numbers Imaginary part Modulus of a complex number',
#        'Conjugate number Real part De Moivre formulas Operations with complex numbers Imaginary part',
#        'Algebraic form Principal argument De Moivre formulas Polar representation Operations with complex numbers Modulus of a complex number Trigonometric form',
#        'Conjugate number Real part Operations with complex numbers Modulus of a complex number Imaginary part',
#        'Algebraic form Principal argument De Moivre formulas Polar representation Trigonometric form Operations with complex numbers Modulus of a complex number',
#        'Operations with complex numbers Modulus of a complex number Algebraic form Principal argument De Moivre formulas Polar representation Trigonometric form',
#        'Trigonometric form Operations with complex numbers Modulus of a complex number Algebraic form Principal argument De Moivre formulas Polar representation',
#        'Operations with complex numbers',
#        'Trigonometric form Modulus of a complex number Algebraic form',
#        'Nth root Polar representation Operations with complex numbers Principal argument De Moivre formulas',
#        'Principal argument Trigonometric form Modulus of a complex number Algebraic form',
#        'Simple graph', 'Platonic solids',
#        'Geometric solids Geometrical figures Classification of geometric solids',
#        'Geometrical figures', 'Platonic solids Regular polygon',
#        'Quadrilaterals Geometrical figures Classification of geometrical figures',
#        'Quadrilaterals Geometrical figures', 'Tree Spanning tree',
#        'Range Kernel Matrix of a linear transformation',
#        'Invertible linear operator Isomorphism Injective linear application',
#        'Linearity Matrix of a linear transformation Linear application',
#        'Linearity Invertible linear operator Composition of linear applications Linear application',
#        'Shortest path Tree Spanning tree Path', 'Substitution',
#        'Substitution Direct inspection Simple integration',
#        'Direct inspection', 'Power of trigonometric functions',
#        'Substitution Direct inspection Integration by parts Rational functions',
#        'Linear independence Span Linear dependence', 'Basis Dimension',
#        'Linear combination Span', 'Subspace Linear combination Span',
#        'Subspace Change-of-basis matrix Linear combination Span Basis',
#        'Change-of-basis matrix Span Basis Dimension',
#        'Subspace Dimension', 'Subspace Basis Dimension',
#        'Euclidean spaces Orthogonal basis Basis',
#        'Linear application Composition of linear applications',
#        'Injective linear application Invertible linear operator Range Kernel Isomorphism',
#        'Basis', 'Linear combination Subspace Span',
#        'Polygons Geometric transformations Geometrical figures',
#        'Polyhedrons Platonic solids Geometric solids',
#        'Polyhedrons Geometric solids Classification of geometric solids',
#        'Polygons Geometrical figures', 'Adjacency matrix Simple graph',
#        'Quadrilaterals Polygons Classification of geometrical figures Geometrical figures',
#        'Adjacency matrix', 'Planar graph',
#        'Event Addition  multiplication  and total probability rules Sample space',
#        'Axioms of probability Event Independence Addition  multiplication  and total probability rules Sample space',
#        'Sample space Addition  multiplication  and total probability rules Axioms of probability Event',
#        'Triangles Triangle inequality', 'Polygons', 'Geometric solids',
#        'Symmetry Geometric transformations', 'Triangles', 'Symmetry',
#        'Triangle inequality Triangles', 'Polygons Regular polygon',
#        'Polygons Triangles', 'Geometrical figures Polygons',
#        'Quadrilaterals Rhombus',
#        'Changing order of integration Cartesian coordinates',
#        'Iterate integrals',
#        'Iterate integrals Area  y-simple region (type I) Cartesian coordinates',
#        'Cartesian coordinates Iterate integrals x-simple region (type II)',
#        'y-simple region (type I) Cartesian coordinates Iterate integrals',
#        'y-simple region (type I) Cartesian coordinates Area  Iterate integrals',
#        'y-simple region (type I) Area  Cartesian coordinates',
#        'Orthogonal projection Distance Cross product Orthogonality',
#        'Cross product Orthogonality Scalar product',
#        'Collinearity Distance Locus Cross product Orthogonality Scalar product',
#        'Distance Cross product Orthogonality', 'Orthogonality',
#        'Orthogonality Cross product',
#        'Orthogonality Distance Scalar product',
#        'Scalar product Orthogonality Orthogonal projection Distance',
#        'Cartesian equations of a plane Orthogonality Locus Distance',
#        'Cartesian equations of a plane Cartesian equations of a line Collinearity',
#        'Locus Distance',
#        'Cross product Cartesian equations of a plane Orthogonality Cartesian equations of a line',
#        'Cartesian equations of a plane Orthogonality',
#        'Cartesian equations of a plane Cartesian equations of a line',
#        'Distance Scalar product Cross product Orthogonality',
#        'Distance Scalar product Cross product Orthogonal projection Orthogonality Collinearity Locus',
#        'Distance Orthogonality Locus',
#        'Cartesian equations of a line Orthogonality Collinearity',
#        'Locus Distance Scalar product Cross product Orthogonality Collinearity',
#        'Intersection Cartesian equations of a plane',
#        'Locus Scalar product Cross product Distance Collinearity Orthogonality',
#        'Orthogonality Locus Scalar product Cross product Collinearity',
#        'Eigenvector Spectrum Characteristic polynomial Eigenvalue',
#        'Spectrum Characteristic polynomial Diagonalization Eigenvalue',
#        'Eigenvector Eigenvalue',
#        'Eigenvector Spectrum Characteristic polynomial Diagonalization Eigenvalue',
#        'Eigenvalue Eigenvector Spectrum Characteristic polynomial',
#        'Eigenvalue Spectrum Diagonalization Characteristic polynomial',
#        'Eigenvalue Eigenvector Diagonalization', 'Eigenvalue Eigenvector',
#        'Eigenvalue Spectrum Eigenvector Characteristic polynomial',
#        'Eigenvalue Spectrum Characteristic polynomial',
#        'Characteristic polynomial Eigenvalue Diagonalization Eigenvector Spectrum',
#        'Determinant properties Inverse matrix  Solve matrix equation Matrix rank Matrix operations Matrix multiplication Symmetric matrix Commuting matrices Determinant computation',
#        'Inverse matrix  Determinant computation Determinant properties Matrix operations',
#        'Commuting matrices Solve matrix equation Matrix equivalent - echelon Inverse matrix  Determinant computation Matrix rank Determinant properties Hermitian matrix Symmetric matrix Matrix multiplication Linearly independent rows Matrix operations',
#        'Symmetric matrix Matrix multiplication Matrix operations',
#        'Commuting matrices Solve matrix equation Matrix equivalent - echelon Inverse matrix  Determinant computation Matrix rank Determinant properties Hermitian matrix Matrix multiplication Linearly independent rows Symmetric matrix Matrix operations',
#        'Commuting matrices Solve matrix equation Matrix equivalent - echelon Determinant computation Matrix rank Inverse matrix  Determinant properties Hermitian matrix Matrix multiplication Linearly independent rows Symmetric matrix Matrix operations',
#        'Matrix rank Linearly independent rows',
#        'Matrix operations Commuting matrices Solve matrix equation Determinant computation Inverse matrix  Matrix rank Determinant properties Matrix multiplication Symmetric matrix',
#        'Matrix multiplication Symmetric matrix Matrix operations',
#        'Matrix multiplication Symmetric matrix Matrix operations Commuting matrices Solve matrix equation Inverse matrix  Determinant computation Matrix rank Determinant properties',
#        'Linearly independent rows Matrix multiplication Symmetric matrix Matrix operations Commuting matrices Solve matrix equation Inverse matrix  Determinant computation Matrix rank Determinant properties',
#        'Linearly independent rows Matrix rank',
#        'Limits Indeterminate forms',
#        'Orthogonality Distance Cross product',
#        'Orthogonality Orthogonal projection Distance',
#        'Cartesian equations of a plane Locus Intersection Cartesian equations of a line',
#        'Collinearity Locus Orthogonality Orthogonal projection Scalar product Distance',
#        'Orthogonality Cross product Distance',
#        'Orthogonality Scalar product',
#        'Simple integration Direct inspection',
#        'Trigonometric rules Quotient rule', 'Integration by parts',
#        'Quotient rule Trigonometric rules Logarithmic rule Product rule',
#        'Quotient rule Trigonometric rules', 'Quotient rule',
#        'Product rule Trigonometric rules Exponential rule',
#        'Linear programming Excel solver add-in Simplex method',
#        'Graphical method Linear programming',
#        'Duality theory Linear programming',
#        'Power rule Quotient rule Product rule Trigonometric rules',
#        'Exponential rule',
#        'Cartesian coordinates x-simple region (type II) Changing order of integration',
#        'Iterate integrals Cartesian coordinates y-simple region (type I)',
#        'Event Sample space Addition  multiplication  and total probability rules Axioms of probability',
#        'Addition  multiplication  and total probability rules',
#        'Injective linear application Invertible linear operator Isomorphism',
#        'Injective linear application Range Kernel Isomorphism',
#        'Simplify expressions Logarithmic function',
#        'Simplify expressions Exponential function',
#        'Square roots Simplify expressions',
#        'Logarithmic function Exponential function Simplify expressions',
#        'Minimum Maximum Stationary point Second derivative test Unconstrained optimization Saddle point Optimal solution',
#        'Optimal solution Minimum Maximum Stationary point Saddle point',
#        'Optimal solution Minimum Maximum Second derivative test Stationary point Unconstrained optimization Saddle point',
#        'Exact differential form Cauchy problem', 'Continuity Limits',
#        'Optimal solution Second derivative test Minimum Maximum Stationary point Saddle point',
#        'Saddle point Optimal solution Minimum Maximum Stationary point',
#        'Lagrange multipliers Optimal solution Minimum Maximum',
#        'Lagrange multipliers Minimum Maximum Stationary point',
#        'Stationary point Maximum Saddle point Optimal solution Minimum',
#        'Stationary point Maximum Saddle point Second derivative test Optimal solution Minimum',
#        'Homogeneous equation', 'Cauchy problem Exact differential form',
#        'Power rule Trigonometric rules Logarithmic rule',
#        'Directional derivative Gradient First order Second order',
#        'Second order', 'Second order First order',
#        'First order Directional derivative',
#        'Bernoulli equation Linear differential equation',
#        'Gradient Directional derivative',
#        'Minimum Maximum Lagrange multipliers Saddle point Unconstrained optimization Second derivative test',
#        'Minimum Stationary point Maximum Saddle point Optimal solution',
#        'Inconsistent system Solution of linear system Undetermined solution of linear system Square linear system Consistent system',
#        'Domain',
#        'Cycle and circuit Shortest path Path Planar graph Tree Adjacency matrix Chromatic number Simple graph Spanning tree Incidence matrix ',
#        'Chromatic number', 'Spanning tree Shortest path Path Tree',
#        'Inconsistent system Solution of linear system Undetermined solution of linear system Homogeneous system Consistent system',
#        'Simplex method Duality theory',
#        'Excel solver add-in Simplex method Linear programming Transportation problem',
#        'Limits',
#        'Optimal solution Minimum Stationary point Maximum Saddle point',
#        'Transportation problem Excel solver add-in Simplex method Linear programming',
#        'Optimal solution Minimum Maximum',
#        'Optimal solution Stationary point Minimum Maximum Saddle point',
#        'Linear programming Assignment problem Excel solver add-in Simplex method',
#        'Simplex method Linear programming Assignment problem Excel solver add-in',
#        'Power rule Trigonometric rules Logarithmic rule First order',
#        'Imaginary part Modulus of a complex number Conjugate number Algebraic form Operations with complex numbers Real part Equations involving complex numbers',
#        'Complex plane ', 'Nonlinear equation Newton\x92s method',
#        'Newton\x92s method Nonlinear equation',
#        "Lagrange's interpolation Polynomial interpolation",
#        'Polynomial interpolation Newton\x92s interpolation',
#        "Polynomial interpolation Lagrange's interpolation",
#        'Newton\x92s interpolation Polynomial interpolation',
#        'Integration by parts Substitution Simple integration Direct inspection',
#        'Union of sets Venn diagram Complement of a set', 'Subset',
#        'Direct integrals  Fundamental theorem of Calculus',
#        'Fundamental theorem of Calculus Direct integrals ',
#        ' Integration by parts Fundamental theorem of Calculus',
#        'Fundamental theorem of Calculus Partial fractions decomposition',
#        'Area of a planar region  Fundamental theorem of Calculus',
#        'Fundamental theorem of Calculus Volume of revolution',
#        'Volume of revolution Fundamental theorem of Calculus',
#        'Mean Median Outliers Interquartile range',
#        'Trigonometric rules Power rule',
#        'Trigonometric rules Product rule Exponential rule',
#        'Unconstrained optimization Second derivative test Optimal solution',
#        'Iterate integrals Cartesian coordinates',
#        'Algebraic form Real part Equations involving complex numbers Imaginary part Conjugate number Modulus of a complex number',
#        'Modulus of a complex number Algebraic form Real part Equations involving complex numbers Imaginary part Conjugate number',
#        'Conjugate number Modulus of a complex number Algebraic form Real part Equations involving complex numbers Imaginary part',
#        'Imaginary part Conjugate number Modulus of a complex number Algebraic form Real part Equations involving complex numbers',
#        'Quadratic equations Simplify expressions Linear equations',
#        'Linear equations Quadratic equations Simplify expressions',
#        'Simplify expressions Linear equations Quadratic equations',
#        'Eigenvector Spectrum Characteristic polynomial Eigenvalue Diagonalization',
#        'Basis Span Subspace Linear combination Dimension',
#        'Solve matrix equation Matrix equivalent - echelon Inverse matrix  Determinant computation Determinant properties Matrix rank Hermitian matrix Matrix operations Symmetric matrix Matrix multiplication Linearly independent rows Commuting matrices',
#        'Orthogonality Orthogonal projection Cross product Scalar product',
#        'Power rule Product rule',
#        'Imaginary part Modulus of a complex number Conjugate number Operations with complex numbers Real part',
#        'Imaginary part Modulus of a complex number Operations with complex numbers Conjugate number Real part',
#        'Linear independence Subspace Linear combination Linear dependence Span',
#        'Nth root Polar representation Imaginary part Complex plane  Operations with complex numbers Real part Principal argument De Moivre formulas',
#        'Basis Span Change-of-basis matrix',
#        'Imaginary part Modulus of a complex number Algebraic form Conjugate number Real part Equations involving complex numbers',
#        'Injective linear application Isomorphism',
#        'Range Kernel Isomorphism Injective linear application',
#        'Distance Orthogonal projection Orthogonality', 'Subspace',
#        'Range Kernel Isomorphism', 'Rotation Linear application',
#        'Span Subspace Linear combination',
#        'Determinant computation Determinant properties Solve matrix equation',
#        'Basis Span', 'Path Cycle and circuit',
#        'Matrix equivalent - echelon Matrix rank Matrix operations Hermitian matrix Matrix multiplication Symmetric matrix Linearly independent rows Commuting matrices Determinant computation Determinant properties Inverse matrix  Solve matrix equation',
#        'Conjugate number Operations with complex numbers',
#        'Euclidean spaces Orthogonal basis',
#        "Conditional probability Bayes' Theorem",
#        'Cross product Orthogonality',
#        'Geometrical figures Quadrilaterals Rhombus',
#        'Sensitivity analysis Postoptimality analysis Duality theory Excel solver add-in Simplex method Linear programming',
#        'Cartesian equations of a plane Intersection Cartesian equations of a line',
#        'Operations with complex numbers Conjugate number',
#        'Triangles Classification of geometrical figures Geometrical figures',
#        "Bayes' Theorem Conditional probability",
#        'Exponential function Simplify expressions', 'Rational functions',
#        'First order Directional derivative Gradient',
#        'Imaginary part Complex plane  Real part',
#        'Product rule Trigonometric rules Quotient rule',
#        'Matrix multiplication Determinant computation Determinant properties Symmetric matrix Hermitian matrix Inverse matrix  Linearly independent rows Commuting matrices Solve matrix equation Matrix operations Matrix rank Matrix equivalent - echelon',
#        'Polar representation Trigonometric form Modulus of a complex number Operations with complex numbers Algebraic form Principal argument De Moivre formulas',
#        'Eigenvalue Diagonalization Spectrum Characteristic polynomial',
#        'Trigonometric rules Product rule Logarithmic rule Exponential rule',
#        'Collinearity Orthogonality Distance Scalar product',
#        'Symmetric matrix Inverse matrix  Hermitian matrix Commuting matrices Linearly independent rows Solve matrix equation Matrix operations Matrix rank Matrix equivalent - echelon Determinant computation Matrix multiplication Determinant properties',
#        'Path Simple graph Cycle and circuit',
#        'Addition  multiplication  and total probability rules Independence Event',
#        'Trigonometric substitution',
#        'Matrix operations Matrix multiplication Determinant computation Determinant properties',
#        'Solution of linear system Undetermined solution of linear system Square linear system Consistent system Inconsistent system',
#        'Directional derivative Gradient',
#        'Matrix operations Inverse matrix ',
#        'Equations involving complex numbers Imaginary part Modulus of a complex number Conjugate number Algebraic form Real part',
#        'Conditional probability',
#        'Adjacency matrix Simple graph Path Shortest path',
#        'Duality theory Excel solver add-in Simplex method Linear programming Sensitivity analysis Postoptimality analysis',
#        'Gradient First order Directional derivative',
#        'Geometrical figures Triangles Classification of geometrical figures',
#        'Simple graph Adjacency matrix',
#        'Postoptimality analysis Duality theory Excel solver add-in Simplex method Linear programming Sensitivity analysis',
#        'Tree Simple graph Spanning tree Path'], dtype=object)

# %%
X['Student Country'].unique()
# Out:
# array(['Ireland', 'Portugal', 'Italy', 'Lithuania', 'Spain',
#        'Russian Federation', 'Romania', 'Slovenia'], dtype=object)

# %%
X['Question ID'].unique()
# Out:
# array([  77,   78,   79,   80,   81,   82,   83,   84,   85,   88,   89,
#          90,   91,   92,   93,   94,   95,   96,   97,   98,  100,  102,
#         104,  108,  112,  113,  114,  118,  120,  122,  123,  125,  127,
#         129,  130,  131,  134,  135,  136,  137,  138,  141,  142,  143,
#         144,  145,  146,  147,  148,  153,  155,  156,  157,  159,  160,
#         164,  165,  168,  169,  172,  177,  178,  179,  180,  181,  182,
#         183,  184,  185,  186,  187,  188,  189,  190,  191,  192,  193,
#         201,  202,  204,  211,  215,  216,  217,  218,  219,  220,  221,
#         222,  223,  224,  225,  227,  228,  229,  230,  231,  233,  234,
#         239,  241,  242,  243,  244,  245,  246,  250,  252,  253,  254,
#         255,  256,  257,  258,  259,  260,  261,  262,  263,  264,  266,
#         267,  268,  269,  270,  271,  272,  273,  274,  275,  277,  279,
#         280,  281,  282,  283,  285,  287,  291,  294,  295,  296,  297,
#         298,  299,  300,  301,  302,  303,  304,  305,  307,  308,  309,
#         311,  313,  314,  316,  317,  319,  321,  323,  324,  325,  326,
#         327,  328,  329,  330,  331,  332,  334,  335,  336,  337,  338,
#         339,  341,  342,  353,  360,  362,  363,  364,  366,  367,  368,
#         369,  371,  374,  375,  376,  377,  378,  379,  383,  384,  386,
#         387,  390,  391,  393,  394,  397,  399,  401,  406,  412,  413,
#         414,  415,  416,  417,  421,  422,  423,  425,  426,  428,  429,
#         431,  433,  434,  435,  436,  437,  438,  443,  444,  450,  452,
#         453,  454,  455,  457,  458,  459,  460,  461,  462,  463,  464,
#         465,  467,  468,  475,  476,  477,  478,  480,  486,  487,  488,
#         489,  492,  493,  494,  495,  496,  497,  501,  502,  503,  504,
#         505,  506,  507,  511,  512,  513,  514,  518,  519,  520,  521,
#         522,  523,  524,  528,  529,  530,  532,  541,  542,  545,  546,
#         547,  548,  549,  551,  552,  553,  554,  555,  556,  557,  558,
#         559,  560,  561,  563,  564,  565,  566,  567,  568,  569,  571,
#         572,  573,  581,  584,  592,  593,  594,  595,  596,  597,  601,
#         602,  603,  604,  605,  606,  607,  608,  611,  612,  613,  614,
#         616,  617,  619,  622,  629,  630,  634,  635,  636,  637,  639,
#         640,  641,  642,  643,  644,  645,  646,  647,  650,  651,  652,
#         653,  657,  658,  661,  665,  666,  667,  668,  671,  672,  678,
#         679,  680,  681,  682,  685,  686,  695,  697,  698,  699,  700,
#         701,  703,  714,  717,  719,  720,  721,  722,  723,  729,  730,
#         733,  734,  735,  736,  737,  738,  741,  742,  743,  744,  752,
#         753,  756,  757,  760,  761,  765,  766,  767,  771,  773,  776,
#         780,  784,  785,  786,  787,  788,  789,  793,  794,  795,  796,
#         798,  818,  820,  821,  828,  829,  831,  832,  834,  835,  836,
#         837,  848,  849,  850,  851,  852,  853,  858,  859,  860,  861,
#         862,  863,  864,  865,  866,  867,  868,  869,  870,  871,  872,
#         873,  874,  875,  876,  877,  878,  879,  883,  885,  888,  889,
#         890,  891,  892,  903,  904,  906,  908,  909,  910,  911,  912,
#         916,  917,  918,  919,  920,  921,  922,  923,  925,  929,  930,
#         933,  935,  936,  940,  942,  943,  946,  947,  948,  949,  950,
#         951,  952,  955,  956,  957,  958,  959,  960,  961,  962,  963,
#         964,  965,  981,  982,  998,  999, 1000, 1001, 1002, 1003, 1004,
#        1005, 1007, 1009, 1010, 1012, 1013, 1014, 1015, 1016, 1020, 1021,
#        1032, 1033, 1052, 1053, 1060, 1061, 1063, 1070, 1071, 1072, 1073,
#        1076, 1080, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094,
#        1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105,
#        1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116,
#        1117, 1118, 1119, 1120, 1121, 1123, 1124, 1125, 1127, 1128, 1131,
#        1132, 1133, 1136, 1138, 1139, 1140, 1141, 1142, 1144, 1146, 1147,
#        1148, 1149, 1150, 1151, 1153, 1157, 1160, 1162, 1163, 1164, 1168,
#        1170, 1173, 1174, 1186, 1197, 1198, 1201, 1202, 1203, 1207, 1208,
#        1212, 1213, 1214, 1215, 1216, 1220, 1226, 1227, 1228, 1229, 1230,
#        1246, 1247, 1248, 1251, 1252, 1473, 1474, 1475, 1477, 1481, 1485,
#        1486, 1487, 1489, 1493, 1495, 1496, 1497, 1514, 1521, 1526, 1549,
#         628,  440,  781,  638,  575,  484,  289,  358,  778,  347,  288,
#         928,  627,  290,  782,  430,  432,  351,  447,  333,  774,  357,
#         783,  132,  306,  427,  570,  380,  420,  448,  292,  382,  779,
#         439,  684,  418,  385,  346,  126,  799,  441,  887,  293,  582,
#         451,  633,  352,  424,  449,  343,  550,  350,  365,  515,  751,
#         278,  792,  683,  696,  354,  340,  498,  446,  509,  471,  359,
#         777,  381,  510,  770,  618,  419,  800, 1067,  983,  410,  880,
#         662,  356, 1084,   87,  676,  802,  727,  318,  348,  405,  121,
#         625,  673,  660,  693,  937,  485,  236,  886,  133,  128,  517,
#         345,  664,  408,  176,  702,  621,  856,  562,  101,  322,  349,
#         677,  624,  670,  576,  574,  355,  472,  516,  124,  938,  926,
#         481, 1066,  491,  732,  687,  139,  249,  881,  469,  674,  718,
#         490,  610,   86,  117,  724,  403,  694,  312,  984,  769,  688,
#         140,  927, 1031,  620, 1054,  763,  663,  372,  857,  473,  746,
#         882,  411,  740,  392,  320,  500, 1056,  775,  854,  456,  373,
#         747,  750,  833,  388,  315,  648,  470,  583,  310,  790,  749,
#         675,  586,  623,  905,  396,  479,  508])

# %%
X['Subtopic'].unique()
# Out:
# array(['Statistics', 'Derivatives', 'Domain, Image and Graphics',
#        'Limits and Continuity', 'Linear Systems',
#        'Algebraic expressions, Equations, and Inequalities',
#        'Matrices and Determinants', 'Differential Equations',
#        'Partial Differentiation', 'Nonlinear Optimization',
#        'Integration Techniques', 'Linear Transformations',
#        'Linear Optimization', 'Probability ', 'Vector Spaces',
#        'Complex Numbers', 'Graph Theory', 'Elementary Geometry',
#        'Double Integration', 'Analytic Geometry',
#        'Eigenvalues and Eigenvectors', 'Numerical Methods', 'Set Theory',
#        'Definite Integrals'], dtype=object)

# %%
X['Topic'].unique()
# Out:
# array(['Statistics', 'Differentiation',
#        'Real Functions of a single variable', 'Linear Algebra',
#        'Fundamental Mathematics', 'Differential Equations',
#        'Optimization', 'Integration', 'Probability ', 'Complex Numbers',
#        'Graph Theory', 'Analytic Geometry', 'Numerical Methods',
#        'Set Theory'], dtype=object)

# %%
X_encoded = pd.get_dummies(X, columns=['Student Country', 'Topic', 'Subtopic', 'Keywords'], drop_first=True)

# %%
# Encode the target if necessary
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Calculate correlations
correlation_matrix = X_encoded.corrwith(pd.Series(y_encoded))
correlation_matrix.sort_values(ascending=False)
# Out:
# Subtopic_Vector Spaces                       0.291471
# Topic_Linear Algebra                         0.256807
# Subtopic_Complex Numbers                     0.217158
# Topic_Complex Numbers                        0.217158
# Keywords_Subspace Linear combination Span    0.123046
#                                                ...
# Subtopic_Numerical Methods                  -0.197437
# Topic_Numerical Methods                     -0.197437
# Topic_Fundamental Mathematics               -0.210184
# Subtopic_Analytic Geometry                  -0.267086
# Question ID                                 -0.803497
# Length: 409, dtype: float64

# %%
print(correlation_matrix.sort_values(ascending=False))
# Out:
# Subtopic_Vector Spaces                       0.291471
# Topic_Linear Algebra                         0.256807
# Subtopic_Complex Numbers                     0.217158
# Topic_Complex Numbers                        0.217158
# Keywords_Subspace Linear combination Span    0.123046
#                                                ...
# Subtopic_Numerical Methods                  -0.197437
# Topic_Numerical Methods                     -0.197437
# Topic_Fundamental Mathematics               -0.210184
# Subtopic_Analytic Geometry                  -0.267086
# Question ID                                 -0.803497
# Length: 409, dtype: float64

# %%
# Dropping 'Keywords' and 'Student ID' columns
df = df.drop(columns=['Keywords', 'Student ID'])
# Verifying the changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9546 entries, 0 to 9545
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student Country  9546 non-null   object
#  1   Question ID      9546 non-null   int64
#  2   Type of Answer   9546 non-null   int64
#  3   Question Level   9546 non-null   object
#  4   Topic            9546 non-null   object
#  5   Subtopic         9546 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 447.6+ KB

# %%
# Remove duplicates
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2868 entries, 0 to 9545
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student Country  2868 non-null   object
#  1   Question ID      2868 non-null   int64
#  2   Type of Answer   2868 non-null   int64
#  3   Question Level   2868 non-null   object
#  4   Topic            2868 non-null   object
#  5   Subtopic         2868 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 156.8+ KB

# %%
# One-Hot Encode 'Student Country', 'Topic', and 'Subtopic'
df_encoded = pd.get_dummies(df, columns=['Student Country', 'Topic', 'Subtopic'], drop_first=True)

# %%
from sklearn.preprocessing import LabelEncoder


# Label Encode 'Question Level' (target variable)
label_encoder = LabelEncoder()
df['Question Level'] = label_encoder.fit_transform(df['Question Level'])

# %%
df_encoded.head()
# Out:
#     Question ID  Type of Answer Question Level  Student Country_Italy  \
# 0            77               0          Basic                  False
# 1            77               1          Basic                  False
# 3            77               0          Basic                   True
# 8            77               0          Basic                  False
# 10           77               0          Basic                  False
#
#     Student Country_Lithuania  Student Country_Portugal  \
# 0                       False                     False
# 1                       False                      True
# 3                       False                     False
# 8                       False                      True
# 10                       True                     False
#
#     Student Country_Romania  Student Country_Russian Federation  \
# 0                     False                               False
# 1                     False                               False
# 3                     False                               False
# 8                     False                               False
# 10                    False                               False
#
#     Student Country_Slovenia  Student Country_Spain  ...  \
# 0                      False                  False  ...
# 1                      False                  False  ...
# 3                      False                  False  ...
# 8                      False                  False  ...
# 10                     False                  False  ...
#
#     Subtopic_Linear Systems  Subtopic_Linear Transformations  \
# 0                     False                            False
# 1                     False                            False
# 3                     False                            False
# 8                     False                            False
# 10                    False                            False
#
#     Subtopic_Matrices and Determinants  Subtopic_Nonlinear Optimization  \
# 0                                False                            False
# 1                                False                            False
# 3                                False                            False
# 8                                False                            False
# 10                               False                            False
#
#     Subtopic_Numerical Methods  Subtopic_Partial Differentiation  \
# 0                        False                             False
# 1                        False                             False
# 3                        False                             False
# 8                        False                             False
# 10                       False                             False
#
#     Subtopic_Probability   Subtopic_Set Theory  Subtopic_Statistics  \
# 0                   False                False                 True
# 1                   False                False                 True
# 3                   False                False                 True
# 8                   False                False                 True
# 10                  False                False                 True
#
#     Subtopic_Vector Spaces
# 0                    False
# 1                    False
# 3                    False
# 8                    False
# 10                   False
#
# [5 rows x 46 columns]

# %%
from sklearn.model_selection import train_test_split


# Define features (X) and target (y)
X = df_encoded.drop(columns=['Question Level'])  # Drop the target column
y = df_encoded['Question Level']  # Target column


# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "SVM": SVC(probability=True, random_state=42)
}

# %%
# Store results
results = {}


for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
   
    # Make predictions
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None
   
    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)
    roc_auc = roc_auc_score(y_test, y_proba, multi_class='ovr') if y_proba is not None else "N/A"
   
    # Save results
    results[model_name] = {
        "Accuracy": accuracy,
        "ROC AUC": roc_auc,
        "Precision (Basic)": report['Basic']['precision'],
        "Recall (Basic)": report['Basic']['recall'],
        "F1-Score (Basic)": report['Basic']['f1-score'],
        "Precision (Advanced)": report['Advanced']['precision'],
        "Recall (Advanced)": report['Advanced']['recall'],
        "F1-Score (Advanced)": report['Advanced']['f1-score']
    }


# Display results
results_df = pd.DataFrame(results).T
results_df
# Out:
# c:\Users\Emmanuel Nti-Asante\Desktop\ETHICS IN AI\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Emmanuel Nti-Asante\Desktop\ETHICS IN AI\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Emmanuel Nti-Asante\Desktop\ETHICS IN AI\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                      Accuracy   ROC AUC  Precision (Basic)  Recall (Basic)  \
# Logistic Regression  0.828107  0.802796           0.827465        0.998584
# Random Forest        0.853659  0.894659           0.915473        0.905099
# Gradient Boosting    0.901278  0.926917           0.895541        0.995751
# SVM                  0.819977  0.590441           0.819977        1.000000
#
#                      F1-Score (Basic)  Precision (Advanced)  \
# Logistic Regression          0.905006              0.888889
# Random Forest                0.910256              0.588957
# Gradient Boosting            0.942991              0.960526
# SVM                          0.901085              0.000000
#
#                      Recall (Advanced)  F1-Score (Advanced)
# Logistic Regression           0.051613             0.097561
# Random Forest                 0.619355             0.603774
# Gradient Boosting             0.470968             0.632035
# SVM                           0.000000             0.000000

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns


# Generate confusion matrix for each model
for model_name, model in models.items():
    # Make predictions
    y_pred = model.predict(X_test)
   
    # Calculate confusion matrix
    cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
   
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=model.classes_, yticklabels=model.classes_)
    plt.title(f'Confusion Matrix for {model_name}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns


# Generate confusion matrix for each model
for model_name, model in models.items():
    # Make predictions
    y_pred = model.predict(X_test)
   
    # Calculate confusion matrix
    cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
   
    # Extract TP, TN, FP, FN
    TP = cm[1, 1]
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
   
    # Print the confusion matrix with TP, TN, FP, FN
    print(f"Confusion Matrix for {model_name}:")
    print(f"TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
   
    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=model.classes_, yticklabels=model.classes_)
    plt.title(f'Confusion Matrix for {model_name}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
# Out:
# Confusion Matrix for Logistic Regression:
# TP: 705, TN: 8, FP: 147, FN: 1
# Confusion Matrix for Random Forest:
# TP: 639, TN: 96, FP: 59, FN: 67
# Confusion Matrix for Gradient Boosting:
# TP: 703, TN: 73, FP: 82, FN: 3
# Confusion Matrix for SVM:
# TP: 706, TN: 0, FP: 155, FN: 0
